# %%
import json
import pandas as pd 
import re
movies_pd = pd.read_json('imdb_top_movies.json')
with open ('imdb_top_movies.json','r',encoding='utf-8') as f :
    movies_js=json.load(f)
print(movies_js)
# Out:
# [{'id': 'tt0111161', 'title': 'The Shawshank Redemption', 'url': 'https://www.imdb.com/title/tt0111161/?ref_=chttp_i_1', 'ranking': '1', 'directors': ['Frank Darabont'], 'writers': ['Stephen King', 'Frank Darabont'], 'stars': ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton'], 'year': '1994', 'level': 'R', 'length': '2h 22m', 'rating': '9.3', 'img': 'images/tt0111161.jpg', 'genres': ['Epic', 'Period Drama', 'Prison Drama', 'Drama'], 'storyline': 'A banker convicted of uxoricide forms a friendship over a quarter century with a hardened convict, while maintaining his innocence and trying to remain hopeful through simple compassion.', 'SCRAPE_TIME': '20251204_135251'}, {'id': 'tt0068646', 'title': 'The Godfather', 'url': 'https://www.imdb.com/title/tt0068646/?ref_=chttp_i_2', 'ranking': '2', 'directors': ['Francis Ford Coppola'], 'writers': ['Mario Puzo', 'Francis Ford Coppola'], 'stars': ['Marlon Brando', 'Al Pacino', 'James Caan'], 'year': '1972', 'level': 'R', 'length': '2h 55m', 'ratin
# ...

# %%
imdb_movies = []
for m in movies_js:
    m['length']=re.search(m['length'],)
