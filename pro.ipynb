# %%
#測試1


from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑


# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://www.imdb.com/chart/top/?ref_=hm_nv_menu")

# %%
#測試2(封面)

search_all = driver.find_elements(By.CSS_SELECTOR,".ipc-metadata-list-summary-item")
search_name = search_all[0].find_element(By.CSS_SELECTOR,"h3").text
search_dec = driver.find_elements(By.CSS_SELECTOR,".ipc-metadata-list-summary-item .sc-432a38ea-6.fhDXpP.cli-title-metadata span")
search_rating = search_all[0].find_element(By.CSS_SELECTOR,".ipc-rating-star--rating").text
search_people= search_all[0].find_element(By.CSS_SELECTOR,".ipc-rating-star--voteCount").text

# %%
#測試3(封面)

all_movie_info = []
cnt = 0

while cnt < 3 :
    for info in search_all :
        info_name=info.find_element(By.CSS_SELECTOR,"h3").text
        info_rating=info.find_element(By.CSS_SELECTOR,".ipc-rating-star--rating").text
        info_peopel= info.find_element(By.CSS_SELECTOR,".ipc-rating-star--voteCount").text
        info_link = info.find_element(By.CSS_SELECTOR,"a").get_attribute("href")
        dec_elems = info.find_elements(By.CSS_SELECTOR, ".sc-432a38ea-6.fhDXpP.cli-title-metadata span")  # 這個 selector 你換成你實際用的

        dec_list = []
        for dec in dec_elems:     # 這裡就會一個一個跑：這部電影的 dec1、dec2、dec3
            dec_list.append(dec.text)
        all_movie_info.append({
            "name": info_name,
            "average_grade": info_rating,
            "rating_people": info_peopel,
            "link": info_link,
            "dec":dec_list,

        })
    
        cnt+=1

# %%
#測試
driver.get("https://www.imdb.com/title/tt0111161/?ref_=chttp_i_1")

# %%
#測試
search_link = search_all[0].find_element(By.CSS_SELECTOR,"a").click()

# %%
#測試4(內頁)

move_info= []
styles_list= []
casts_list=[]
move_zhname=driver.find_element(By.CSS_SELECTOR,".hero__primary-text").text
move_ehname=driver.find_element(By.CSS_SELECTOR,".sc-16bda17f-2.xWWWN.baseAlt").text
move_rating=driver.find_element(By.CSS_SELECTOR,".sc-4dc495c1-1.lbQcRY").text
move_ratingpeople=driver.find_element(By.CSS_SELECTOR,".sc-4dc495c1-3.eNfgcR").text
move_img=driver.find_element(By.CSS_SELECTOR,".ipc-lockup-overlay.ipc-focusable.ipc-focusable--constrained").get_attribute("href")
move_cast=driver.find_elements(By.CSS_SELECTOR,".sc-10bde568-5.dWhYSc .sc-10bde568-1.jBmamV")
move_styles=driver.find_elements(By.CSS_SELECTOR,".ipc-chip-list__scroller span")
print(move_styles[0].text)
for styles in move_styles:
    styles_list.append(styles.text)


for cast in move_cast:
    casts_list.append(cast.text)

move_info.append({"zhname":move_zhname,
                "ehname":move_ehname,
                "rating":move_rating,
                "ratingpeople":move_ratingpeople,
                "move_img":move_img,
                "styles":styles_list,
                "move_casts":casts_list})
# Out:
# 史詩

# %%
#整理
all_movie_info = []
cnt = 0

while cnt < 3 :
    for info in search_all :
        info_name=info.find_element(By.CSS_SELECTOR,"h3").text
        info_link = info.find_element(By.CSS_SELECTOR,"a").get_attribute("href")
        all_movie_info.append({
            "name": info_name,
            "link": info_link,

        })
    
        cnt+=1

# %%
#最後1

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑


# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://www.imdb.com/chart/top/?ref_=hm_nv_menu")

# %%
#最後2

movie_link = []
all_movie_detail=[]
cnt = 0
search_all = driver.find_elements(By.CSS_SELECTOR,".ipc-metadata-list-summary-item")

for info in search_all[:3] :
        info_name = info.find_element(By.CSS_SELECTOR,"h3").text
        info_link = info.find_element(By.CSS_SELECTOR,"a").get_attribute("href")
        dec_elems = info.find_elements(By.CSS_SELECTOR, ".sc-432a38ea-6.fhDXpP.cli-title-metadata span")  # 這個 selector 你換成你實際用的

        dec_list = []
        for dec in dec_elems:     # 這裡就會一個一個跑：這部電影的 dec1、dec2、dec3
            dec_list.append(dec.text)
        movie_link.append({
            "name": info_name,
            "link": info_link,
            "dec":dec_list

        })
    
        cnt+=1

def get_all_comment(url):
    driver.get(url)
    styles_list= []
    casts_list=[]
    
    move_zhname=driver.find_element(By.CSS_SELECTOR,".hero__primary-text").text
    move_ehname=driver.find_element(By.CSS_SELECTOR,".sc-16bda17f-2.xWWWN.baseAlt").text
    move_rating=driver.find_element(By.CSS_SELECTOR,".sc-4dc495c1-1.lbQcRY").text
    move_ratingpeople=driver.find_element(By.CSS_SELECTOR,".sc-4dc495c1-3.eNfgcR").text
    move_img=driver.find_element(By.CSS_SELECTOR,".ipc-lockup-overlay.ipc-focusable.ipc-focusable--constrained").get_attribute("href")
    move_cast=driver.find_elements(By.CSS_SELECTOR,".sc-10bde568-5.dWhYSc .sc-10bde568-1.jBmamV")
    move_styles=driver.find_elements(By.CSS_SELECTOR,".ipc-chip-list__scroller span")
   

   

    for styles in move_styles:
        styles_list.append(styles.text)


    for cast in move_cast:
        casts_list.append(cast.text)

   

        
    return {"zhname":move_zhname,
                    "ehname":move_ehname,
                    "rating":move_rating,
                    "ratingpeople":move_ratingpeople,
                    "move_img":move_img,
                    "styles":styles_list,
                    "move_casts":casts_list,
                    }

for m in movie_link:
    detail = get_all_comment(m['link'])
    all_movie_detail.append(detail)

# %%
#最後3

print(all_movie_detail)
import json
with open('try.json','w',encoding='utf-8')as f:
            json.dump(all_movie_detail,f,indent=4,ensure_ascii=False)

import json
with open('trylink.json','w',encoding='utf-8')as f:
            json.dump(movie_link,f,indent=4,ensure_ascii=False)
# Out:
# [{'zhname': '刺激1995', 'ehname': 'Original title: The Shawshank Redemption', 'rating': '9.3', 'ratingpeople': '3.1M', 'move_img': 'https://www.imdb.com/title/tt0111161/mediaviewer/rm1690056449/?ref_=tt_ov_i', 'styles': ['史詩', '時代劇情片', '監獄劇', '戲劇', 'Authentic emotion', 'Character development', 'Emotional weight', 'Enduring legacy', 'Friendship', 'Inspirational', 'Performance', 'Cinematography', 'Narration'], 'move_casts': ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton', 'William Sadler', 'Clancy Brown', 'Gil Bellows', 'Mark Rolston', 'James Whitmore', 'Jeffrey DeMunn', 'Larry Brandenburg', 'Neil Giuntoli', 'Brian Libby', 'David Proval', 'Joseph Ragno', 'Jude Ciccolella', 'Paul McCrane', 'Renee Blaine', 'Scott Mann']}, {'zhname': '教父', 'ehname': 'Original title: The Godfather', 'rating': '9.2', 'ratingpeople': '2.2M', 'move_img': 'https://www.imdb.com/title/tt0068646/mediaviewer/rm746868224/?ref_=tt_ov_i', 'styles': ['史詩', '悲劇', '黑幫', '戲劇', '犯罪', 'Atmospheric', 'Authentic emotion', 'Character development', 'Cinematography', 'Direction', 'Enduring legacy', 'Family dynamics', 'Iconic lines', 'Iconic performance', 'Narrative complexity'], 'move_casts': ['Marlon Brando', 'Al Pacino', 'James Caan', 'Richard S. Castellano', 'Robert Duvall', 'Sterling Hayden', 'John Marley', 'Richard Conte', 'Al Lettieri', 'Diane Keaton', 'Abe Vigoda', 'Talia Shire', 'Gianni Russo', 'John Cazale', 'Rudy Bond', 'Al Martino', 'Morgana King', 'Lenny Montana']}, {'zhname': '黑暗騎士', 'ehname': 'Original title: The Dark Knight', 'rating': '9.1', 'ratingpeople': '3.1M', 'move_img': 'https://www.imdb.com/title/tt0468569/mediaviewer/rm4023877632/?ref_=tt_ov_i', 'styles': ['史詩', '史詩動作片', '心理劇情片', '心理驚悚', '悲劇', '超級英雄', '動作', '戲劇', '犯罪', '驚悚片', 'Action sequences', 'Cinematography', 'Direction', 'Standout performance', 'Adaptation', 'Dark tone', 'Philosophical elements', 'Character development', 'Pacing'], 'move_casts': ['Christian Bale', 'Heath Ledger', 'Aaron Eckhart', 'Michael Caine', 'Maggie Gyllenhaal', 'Gary Oldman', 'Morgan Freeman', 'Monique Gabriela Curnen', 'Ron Dean', 'Cillian Murphy', 'Chin Han', 'Nestor Carbonell', 'Eric Roberts', 'Ritchie Coster', 'Anthony Michael Hall', 'Keith Szarabajka', 'Colin McFarlane', 'Joshua Harto']}]
